# %%
#Install all the Reqiuired Libraries and Packages 
import os
import glob
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc , logfbank
import librosa as lr
import pickle
from scipy import signal
import noisereduce as nr
from glob import glob
from tqdm.auto import tqdm
get_ipython().magic('matplotlib inline')
#All the Required Packages and Libraies are installed.
import soundfile
from tensorflow.keras.layers import Conv2D,MaxPool2D, Flatten, LSTM
from keras.layers import Dropout,Dense,TimeDistributed
from keras.models import Sequential
from keras.utils import to_categorical 
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
# Out:
# C:\Users\Prashant\anaconda3\lib\site-packages\noisereduce\noisereduce.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import os
os.getcwd()
import librosa

# %%
#Loading the required RAVDESS DataSet with length of 1439 Audio Files 
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
# ////print(BASE_DIR)
os.listdir(path='.\speech-emotion-recognition-ravdess-data')
def getListOfFiles(dirName):
    listOfFile=os.listdir(dirName)
    allFiles=list()
    for entry in listOfFile:
        fullPath=os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles=allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
    return allFiles

dirName = './speech-emotion-recognition-ravdess-data'
listOfFiles = getListOfFiles(dirName)
len(listOfFiles)
# Out:
# 1439

# %%
#Use the Speech-Recognition API to get the Raw Text from Audio Files, Though Speech Recognition
#is less strong for large chunk of files , so used Error Handling , where when it is not be able to 
#produce the text of a particular Audio File it prints the statement 'error'.Just for understanding Audio
import speech_recognition as sr
r=sr.Recognizer()
for file in range(0 , len(listOfFiles) , 1):
    with sr.AudioFile(listOfFiles[file]) as source:
        audio = r.listen(source)
        try:
            text = r.recognize_google(audio)
            print(text)
        except:
            print('error')
# Out:
# is it talking by the door
# dog sitting by the door
# talk to Siri why the door
# error
# error
# error
# dog sitting by the door
# change your talking by the door
# kids talking by the door
# dogs sitting by the door
# sitting by the
# kids talking by the door
# talking by the door
# dog sitting by the door
# error
# talking by the door
# error
# sitting by the door
# error
# kids talking by the door
# khesa talking by the door
# error
# error
# kids talking by the door
# talking by the door
# dogs sitting by the door
# sitting by the door
# talking by the door
# is a talking by the door
# the door
# error
# the door
# Earth talking by the door
# frogs are sitting by the door
# dogs are sitting at the door
# talking by the door
# kids talking by the door
# dogs sitting by the door
# dogs sitting by the door
# f****** by the door
# is the talking to the door
# Rockstar ceiling by the door
# ceiling by the
# error
# khinch
# sitting by the door
# coronavirus
# kids talking by the door
# talking by the door
# tour tour
# exit the door
# kids talking
# kids talking by the door
# dogs sitting by the door
# error
# Ijjat
# talking by the door
# sitting by the door
# toxicity by the door
# kids talking by the door
# kids talking by the door
# dogs are sitting by the door
# talk just sitting by the door
# it's a talking by the door
# hits at hacking by the door
# dogs are sitting by the tower
# sitting by the door
# kids talking by the
# kids attacking Bible
# dogs are sitting by the door
# tags setting
# talking by the door
# error
# dogs are sitting by the door
# dogs are sitting by the door
# error
# error
# jobs in sitting by the driver
# Jhansi
# Ijjat Hawking by the tour
# talking by the door
# dogs sitting by the door
# target setting by the tour
# talking by the tour
# Ijjat hacking by the to
# talk with sitting by the tour
# talk was sitting by the tour
# talking by the door
# error
# dog sitting by the door
# dog sitting by the door
# talking by the door
# kids talking about the door
# dogs are standing by the door
# dogs sitting by the door
# talking by the door
# talking by the Joker
# tox was sitting by the Joker
# talk just sitting by the Shore
# error
# Talking Ben the dog
# talks of cinema
# error
# talking by the door
# f****** by the door
# error
# error
# kids f****** by the door
# kids talking by the door
# dogs staring by the door
# dogs staring by the door
# talking by the door
# talking by the door
# sitting by the door
# talk to setting by the door
# the door
# error
# error
# error
# talking by the door
# talking
# sitting by the door
# charger sitting by the door
# talking Titan
# talking by the door
# error
# Siri
# talking by the door
# talking bicycle
# error
# charge sharing by the tour
# error
# by the door
# sitting by the Shore
# sitting by the door
# whore
# kids are talking
# talk to the door
# sitting by the door
# Satta King
# hit the talking by the door
# set setting
# search string by date
# Pitbull
# error
# error
# ek baat Bataun
# talking part 2
# talking
# accident
# error
# balto
# talking toe
# error
# error
# talking
# are talking by the door
# torturing fight over
# Ram Charan father
# error
# which is the tour
# error
# shortest path
# Jharkhand
# talking
# sharing button
# thought that setting barbacoa
# hot
# Chetan
# dogs are sitting pattern
# sitting by the door
# error
# error
# error
# ceiling fan
# error
# error
# error
# staring at the door
# talking by the door
# talking by the door
# dog racing by the door
# top 10 sitting by the door
# talking by the driver
# talking by the dohe
# dogs sitting by the door
# dogs at sitting batua
# kids at hacking but it over
# talking by the tower
# Agra sitting by the tower
# dogs sitting at the door
# the talking by the river
# talking by the door
# Etawah
# chocolate selling by the Joker
# the talking by the door
# talking baddua
# stop the string that over
# error
# talking by the tower
# the talking by the door
# stop the sitting by the door
# top 10 sitting by the door
# error
# weather tour
# error
# error
# talking by the door
# error
# sitting by the door
# dog sitting by the door
# error
# error
# show the sitting by the drawer
# error
# talking by the door
# talking by the door
# stock was sitting by the door
# sitting by the door
# error
# error
# error
# error
# shit talking by the door
# talking but the door
# dog sitting by the door
# setting button
# talking by the door
# talking by the door
# top 10 sitting by the door
# stock that ceiling budget tour
# Utha Ke Mare Jor
# talking by the door
# sitting by the door
# sitting by the door
# at the door
# ki badi Jor
# error
# error
# kids are talking by the door
# kids are talking by the door
# dogs setting bar the door
# dogs are sitting by the door
# kids are talking by the door
# kids are talking
# dogs are sitting party door
# dogs are sitting by the door
# Kates 8 parking
# shades
# error
# dogs are sitting
# kids talking by the door
# talking by the door
# error
# dogs sitting by the door
# Kids Art
# Khet aur talking by the door
# error
# the door
# kids talking by the door
# kids are talking by the door
# talk it over
# dogs are sitting by the door
# error
# Khesari talking at the door
# roxid syrup
# transistor in motherboard
# are talking by the
# kids are talking by the door
# dogs are sitting by the door
# error
# kids talking by the door
# tricks of talking for the tour
# ostrich
# auto
# error
# kids talking
# error
# error
# talking or
# Kids Art
# talk it over
# Georgette saree madarchod
# Kids Art talking
# Khet Jaat Hawking
# error
# error
# kids are talking
# kids are talking
# sharing
# no
# error
# kids out of the door
# error
# error
# kids are talking
# error
# error
# Shri
# kids talking by the door
# kids are talking by the door
# talk the sitting by the door
# ok just sitting by the door
# talking
# talking by the door
# Jagdish tearing by the door
# jagra staring by the
# error
# error
# Jug staring by the door
# chagas ring by with
# talking by the door
# error
# dog racing Bai wadyavar
# sitting by the door
# error
# error
# error
# error
# kids talking by the door
# talking by the door
# dogs are sitting by the door
# dogs selling by the door
# error
# error
# error
# stock
# talking by the door
# talking by the door
# dog sitting by the door
# dog sitting by the door
# error
# error
# error
# error
# error
# kids talking by the door
# error
# error
# error
# error
# error
# error
# error
# error
# dogs sitting by the door
# Marxist theory by withdrawal
# error
# talking bhai
# error
# Tik Tok best ringtone
# the talking by the door
# Kidhar talking by the door
# error
# error
# talking
# error

# %%
#Now Cleaning Step is Performed where:
#DOWN SAMPLING OF AUDIO FILES IS DONE  AND PUT MASK OVER IT AND DIRECT INTO CLEAN FOLDER
#MASK IS TO REMOVE UNNECESSARY EMPTY VOIVES AROUND THE MAIN AUDIO VOICE 
def envelope(y , rate, threshold):
    mask=[]
    y=pd.Series(y).apply(np.abs)
    y_mean = y.rolling(window=int(rate/10) ,  min_periods=1 , center = True).mean()
    for mean in y_mean:
        if mean>threshold:
            mask.append(True)
        else:
            mask.append(False)
    return mask

# %%
#Plotting the Basic Graphs for understanding of Audio Files :
for file in range(0 , len(listOfFiles) , 1):
    audio , sfreq = lr.load(listOfFiles[file])
    time = np.arange(0 , len(audio)) / sfreq
    
    fig ,ax = plt.subplots()
    ax.plot(time , audio)
    ax.set(xlabel = 'Time (s)' , ylabel = 'Sound Amplitude')
    plt.show()
    
#PLOT THE SEPCTOGRAM
for file in range(0 , len(listOfFiles) , 1):
     sample_rate , samples = wavfile.read(listOfFiles[file])
     frequencies , times, spectrogram = signal.spectrogram(samples, sample_rate) 
     plt.pcolormesh(times, frequencies, spectrogram)
     plt.imshow(spectrogram)
     plt.ylabel('Frequency [Hz]')
     plt.xlabel('Time [sec]')
     plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-aa566e6b3fc6> in <module>
#       1 #Plotting the Basic Graphs for understanding of Audio Files :
#       2 for file in range(0 , len(listOfFiles) , 1):
# ----> 3     audio , sfreq = lr.load(listOfFiles[file])
#       4     time = np.arange(0 , len(audio)) / sfreq
#       5
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     170
#     171     if sr is not None:
# --> 172         y = resample(y, sr_native, sr, res_type=res_type)
#     173
#     174     else:
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     582         y_hat = samplerate.resample(y.T, ratio, converter_type=res_type).T
#     583     else:
# --> 584         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     585
#     586     if fix:
#
# ~\anaconda3\lib\site-packages\resampy\core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:

# %%
#Next Step is In-Depth Visualisation of Audio Fiels and its certain features to plot for.
#They are the Plotting Functions to be called later. 
def plot_signals(signals):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Time Series' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(signals.keys())[i])
            axes[x,y].plot(list(signals.values())[i])
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1

def plot_fft(fft):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Fourier Transform' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            data = list(fft.values())[i]
            Y,freq = data[0] , data[1]
            axes[x,y].set_title(list(fft.keys())[i])
            axes[x,y].plot(freq , Y)
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1
    
def plot_fbank(fbank):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Filter Bank Coefficients' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(fbank.keys())[i])
            axes[x,y].imshow(list(fbank.values())[i],cmap='hot', interpolation = 'nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1
            
def plot_mfccs(mfccs):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Mel Frequency Capstrum  Coefficients' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(mfccs.keys())[i])
            axes[x,y].imshow(list(mfccs.values())[i],
                             cmap='hot', interpolation = 'nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1

def calc_fft(y,rate):
    n = len(y)
    freq = np.fft.rfftfreq(n , d= 1/rate)
    Y= abs(np.fft.rfft(y)/n)
    return(Y,freq)

# %%
# Here The Data Set is loaded and plots are Visualised by Calling the Plotting Functions . 
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
for file in range(0 , len(listOfFiles) , 1):
    rate, data = wav.read(listOfFiles[file])
    fft_out = fft(data)
    # %matplotlib inline
    plt.plot(data, np.abs(fft_out))
    plt.show()
    
signals={}
fft={}
fbank={}
mfccs={}
# load data
for file in range(0 , len(listOfFiles) , 1):
#     rate, data = wavfile.read(listOfFiles[file])
     signal,rate =librosa.load(listOfFiles[file] , sr=44100)
     mask = envelope(signal , rate , 0.0005)
     signals[file] = signal
     fft[file] = calc_fft(signal , rate)
    
     bank = logfbank(signal[:rate] , rate , nfilt = 26, nfft = 1103).T
     fbank[file] = bank
     mel = mfcc(signal[:rate] , rate , numcep =13 , nfilt = 26 , nfft=1103).T
     mfccs[file]=mel

plot_signals(signals)
plt.show()

plot_fft(fft)
plt.show()

plot_fbank(fbank)
plt.show()

plot_mfccs(mfccs)
plt.show()

# %%
#Now Cleaning Step is Performed where:
#DOWN SAMPLING OF AUDIO FILES IS DONE  AND PUT MASK OVER IT AND DIRECT INTO CLEAN FOLDER
#MASK IS TO REMOVE UNNECESSARY EMPTY VOIVES AROUND THE MAIN AUDIO VOICE 
def envelope(y , rate, threshold):
    mask=[]
    y=pd.Series(y).apply(np.abs)
    y_mean = y.rolling(window=int(rate/10) ,  min_periods=1 , center = True).mean()
    for mean in y_mean:
        if mean>threshold:
            mask.append(True)
        else:
            mask.append(False)
    return mask

# %%
#The clean Audio Files are redirected to Clean Audio Folder Directory 
import glob,pickle
for file in tqdm(glob.glob(r'C:\Users\Prashant\Desktop\speech\speech-emotion-recognition-ravdess-data\\**\\*.wav')):
    file_name = os.path.basename(file)
    signal , rate = librosa.load(file, sr=16000)
    mask = envelope(signal,rate, 0.0005)
    wavfile.write(filename= r'C:\Users\Prashant\Desktop\speech\clean_speech\\'+str(file_name), rate=rate,data=signal[mask])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1439.0), HTML(value='')))

# %%
#Feature Extraction of Audio Files Function 
#Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result=np.hstack((result, mel))
    return result

# %%
#Emotions in the RAVDESS dataset to be classified Audio Files based on . 
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
#These are the emotions User wants to observe more :
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
#Load the data and extract features for each sound file
from glob import glob
import os
import glob
def load_data(test_size=0.33):
    x,y=[],[]
    answer = 0
    for file in glob.glob(r'C:\Users\Prashant\Desktop\speech\clean_speech\\*.wav'):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            answer += 1
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append([emotion,file_name])
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
#Split the dataset
import librosa
import numpy as np
x_train,x_test,y_trai,y_tes=load_data(test_size=0.25)
print(np.shape(x_train),np.shape(x_test), np.shape(y_trai),np.shape(y_tes))
y_test_map = np.array(y_tes).T
y_test = y_test_map[0]
test_filename = y_test_map[1]
y_train_map = np.array(y_trai).T
y_train = y_train_map[0]
train_filename = y_train_map[1]
print(np.shape(y_train),np.shape(y_test))
print(*test_filename,sep="\n")
# Out:
# (576, 180) (192, 180) (576, 2) (192, 2)
# (576,) (192,)
# 03-01-06-01-02-02-01.wav
# 03-01-03-01-02-01-21.wav
# 03-01-07-01-02-02-04.wav
# 03-01-02-02-01-02-24.wav
# 03-01-07-01-02-02-19.wav
# 03-01-06-01-01-01-07.wav
# 03-01-07-01-01-01-16.wav
# 03-01-02-01-02-02-06.wav
# 03-01-06-01-01-02-07.wav
# 03-01-06-02-01-01-15.wav
# 03-01-02-02-02-02-07.wav
# 03-01-06-01-02-02-19.wav
# 03-01-06-02-02-02-05.wav
# 03-01-06-01-01-01-14.wav
# 03-01-06-01-02-01-15.wav
# 03-01-03-02-02-01-06.wav
# 03-01-02-01-01-02-16.wav
# 03-01-07-01-01-01-13.wav
# 03-01-03-02-02-02-24.wav
# 03-01-02-01-02-02-19.wav
# 03-01-02-02-01-02-09.wav
# 03-01-02-01-01-02-07.wav
# 03-01-03-01-02-01-13.wav
# 03-01-02-01-02-01-18.wav
# 03-01-02-02-02-02-03.wav
# 03-01-02-02-01-01-11.wav
# 03-01-03-01-02-02-20.wav
# 03-01-03-02-01-02-06.wav
# 03-01-06-01-01-02-11.wav
# 03-01-03-01-02-01-18.wav
# 03-01-06-01-01-01-15.wav
# 03-01-07-02-01-02-08.wav
# 03-01-07-02-01-02-23.wav
# 03-01-03-01-02-02-10.wav
# 03-01-06-01-01-01-23.wav
# 03-01-07-02-02-01-18.wav
# 03-01-06-02-02-01-22.wav
# 03-01-07-02-01-01-21.wav
# 03-01-07-01-01-02-10.wav
# 03-01-06-02-01-01-01.wav
# 03-01-07-02-01-02-17.wav
# 03-01-02-02-02-02-17.wav
# 03-01-03-01-01-01-04.wav
# 03-01-06-02-02-01-24.wav
# 03-01-06-02-02-01-10.wav
# 03-01-02-02-01-02-12.wav
# 03-01-06-02-01-02-01.wav
# 03-01-07-01-01-01-10.wav
#         5.29628422e-04,  1.21785991e-03,  1.94199232e-03,  2.71616247e-03,
#         3.02916719e-03,  1.52156025e-03,  1.43521861e-03,  1.66917243e-03,
#         8.84747016e-04,  4.41883836e-04,  1.73531371e-04,  1.87186262e-04,
#         6.13943965e-04,  5.82709152e-04,  8.44499969e-04,  8.81950895e-04,
#         1.17025815e-03,  1.69659348e-03,  1.37144874e-03,  1.97844068e-03,
#         1.36995281e-03,  1.02335657e-03,  7.40832009e-04,  4.85167839e-04,
#         5.40740381e-04,  4.51232307e-04,  4.60240262e-04,  4.31887747e-04,
#         3.21824482e-04,  2.61257548e-04,  1.54117253e-04,  1.24791535e-04,
#         1.20981735e-04,  1.21211633e-04,  8.49588905e-05,  7.63957869e-05,
#         1.57911927e-04,  1.84706325e-04,  1.15843526e-04,  6.19651400e-05]))
# Features extracted: 180

# %%
# Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
#Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
#SAVING THE MODEL
import pickle
# Save the Modle to file in the current working directory
#For any new testing data other than the data in dataset

Pkl_Filename = "Emotion_Voice_Detection_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)

# %%
# Load the Model back from file
with open(Pkl_Filename, 'rb') as file:  
    Emotion_Voice_Detection_Model = pickle.load(file)

Emotion_Voice_Detection_Model
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
#predicting :
y_pred=Emotion_Voice_Detection_Model.predict(x_test)
y_pred
# Out:
# array(['disgust', 'happy', 'fearful', 'calm', 'disgust', 'calm',
#        'disgust', 'disgust', 'fearful', 'fearful', 'calm', 'fearful',
#        'fearful', 'fearful', 'disgust', 'fearful', 'disgust', 'disgust',
#        'fearful', 'calm', 'calm', 'disgust', 'happy', 'calm', 'disgust',
#        'calm', 'disgust', 'happy', 'disgust', 'calm', 'calm', 'happy',
#        'disgust', 'happy', 'fearful', 'disgust', 'fearful', 'disgust',
#        'happy', 'disgust', 'disgust', 'calm', 'disgust', 'fearful',
#        'fearful', 'calm', 'fearful', 'happy', 'calm', 'calm', 'disgust',
#        'fearful', 'happy', 'disgust', 'disgust', 'disgust', 'disgust',
#        'disgust', 'happy', 'calm', 'disgust', 'happy', 'disgust',
#        'fearful', 'disgust', 'fearful', 'disgust', 'fearful', 'fearful',
#        'disgust', 'disgust', 'calm', 'disgust', 'calm', 'happy', 'calm',
#        'disgust', 'disgust', 'happy', 'happy', 'disgust', 'happy',
#        'fearful', 'happy', 'disgust', 'fearful', 'disgust', 'disgust',
#        'disgust', 'fearful', 'calm', 'fearful', 'happy', 'happy', 'calm',
#        'calm', 'fearful', 'disgust', 'disgust', 'fearful', 'disgust',
#        'fearful', 'happy', 'fearful', 'calm', 'disgust', 'calm', 'calm',
#        'calm', 'calm', 'fearful', 'disgust', 'happy', 'calm', 'disgust',
#        'calm', 'calm', 'disgust', 'calm', 'happy', 'happy', 'fearful',
#        'calm', 'calm', 'calm', 'calm', 'fearful', 'disgust', 'calm',
#        'fearful', 'fearful', 'happy', 'disgust', 'disgust', 'happy',
#        'disgust', 'disgust', 'disgust', 'disgust', 'happy', 'disgust',
#        'disgust', 'disgust', 'calm', 'fearful', 'happy', 'fearful',
#        'fearful', 'disgust', 'disgust', 'disgust', 'fearful', 'calm',
#        'calm', 'disgust', 'disgust', 'fearful', 'happy', 'disgust',
#        'calm', 'calm', 'calm', 'fearful', 'disgust', 'calm', 'fearful',
#        'happy', 'fearful', 'fearful', 'happy', 'fearful', 'fearful',
#        'disgust', 'disgust', 'calm', 'disgust', 'happy', 'disgust',
#        'calm', 'disgust', 'fearful', 'fearful', 'happy', 'fearful',
#        'fearful', 'fearful', 'disgust', 'disgust', 'happy', 'fearful',
#        'disgust', 'calm'], dtype='<U7')

# %%
#Store the Prediction probabilities into CSV file 
import numpy as np
import pandas as pd
y_pred1 = pd.DataFrame(y_pred, columns=['predictions'])
y_pred1['file_names'] = test_filename
print(y_pred1)
y_pred1.to_csv('predictionfinal.csv')
# Out:
#     predictions                file_names
# 0       disgust  03-01-06-01-02-02-01.wav
# 1         happy  03-01-03-01-02-01-21.wav
# 2       fearful  03-01-07-01-02-02-04.wav
# 3          calm  03-01-02-02-01-02-24.wav
# 4       disgust  03-01-07-01-02-02-19.wav
# ..          ...                       ...
# 187     disgust  03-01-07-01-02-02-14.wav
# 188       happy  03-01-03-02-02-02-02.wav
# 189     fearful  03-01-06-02-01-01-14.wav
# 190     disgust  03-01-07-01-01-02-02.wav
# 191        calm  03-01-02-02-02-01-22.wav
#
# [192 rows x 2 columns]

# %%
#RECORDED USING MICROPHONE:
import pyaudio
import wave
import librosa
import matplotlib.pyplot as plt
import soundfile
import numpy as np

import pickle
# Save the Modle to file in the current working directory
#For any new testing data other than the data in dataset
with open(Pkl_Filename, 'rb') as file:  
    Emotion_Voice_Detection_Model = pickle.load(file)

Pkl_Filename = "Emotion_Voice_Detection_Model.pkl"  


def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result=np.hstack((result, mel))
    return result

CHUNK = 1024 
FORMAT = pyaudio.paInt16 #paInt8
CHANNELS = 1
RATE = 44100 #sample rate
RECORD_SECONDS = 4
WAVE_OUTPUT_FILENAME = "output10.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK) #buffer

print("* recording")
frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data) # 2 bytes(16 bits) per channel

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# * recording
# * done recording

# %%
#The file 'output10.wav' in the next cell is the file that was recorded live using the code :
data, sampling_rate = librosa.load('output10.wav')
# %matplotlib inline
import os
import pandas as pd
import librosa.display
import glob 


plt.figure(figsize=(15, 5))
librosa.display.waveplot(data, sr=sampling_rate)
